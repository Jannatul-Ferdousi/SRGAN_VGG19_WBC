# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance as dist
import matplotlib.pyplot as plt
import os
import cv2
import seaborn as sns
from tqdm import tqdm 
from sklearn.utils import shuffle
from sklearn import decomposition
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import tensorflow as tf
import keras
from keras.applications.vgg16 import VGG16 
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.models import Sequential, Model 
from keras.applications import DenseNet201
from keras.initializers import he_normal
from keras.layers import Lambda, SeparableConv2D, BatchNormalization, Dropout, MaxPooling2D, Input, Dense, Conv2D, Activation, Flatten 
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import imutils
import keras.backend as K


K.clear_session()
# Out:
# 2023-11-21 16:37:14.992094: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-21 16:37:15.016481: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 16:37:15.016511: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 16:37:15.016537: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 16:37:15.021422: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-21 16:37:15.465368: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def findEdges(image):
    # find edges in image
    gray = cv2.GaussianBlur(image, (1, 1), 0)
    edged = cv2.Canny(gray, 100, 400)
    edged = cv2.dilate(edged, None, iterations=1)
    edged = cv2.erode(edged, None, iterations=1)
    return edged

# %%
def getImgContours(edged):
    # find contours in the edge map
    contours = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(contours)
    contours = sorted(contours, key=lambda x: cv2.contourArea(x))
    return contours

# %%
def getBoxes(contours, orig):
    # get the boxes
    boxes = []
    centers = []
    for contour in contours:
        box = cv2.minAreaRect(contour)
        box = cv2.cv.BoxPoints(box) if imutils.is_cv2() else cv2.boxPoints(box)
        box = np.array(box, dtype="int")
        (tl, tr, br, bl) = box
        if (dist.euclidean(tl, bl)) > 0 and (dist.euclidean(tl, tr)) > 0:
            boxes.append(box)
    return boxes

# %%
class_names = ['EOSINOPHIL', 'LYMPHOCYTE', 'MONOCYTE', 'NEUTROPHIL']
nb_classes = len(class_names)
image_size = (128, 128)

# %%
def load_data(path):

    datasets = [path]
    images = []
    labels = []

    # iterate through training and test sets
    count =0
    for dataset in datasets:

        # iterate through folders in each dataset
        for folder in os.listdir(dataset):

            if folder in ['EOSINOPHIL']: label = 0
            elif folder in ['LYMPHOCYTE']: label = 1
            elif folder in ['MONOCYTE']: label = 2
            elif folder in ['NEUTROPHIL']: label = 3

            # iterate through each image in folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):

                # get pathname of each image
                img_path = os.path.join(os.path.join(dataset, folder), file)

                # Open 
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                
                # add padding to the image to better detect cell at the edge
                image = cv2.copyMakeBorder(image,10,10,10,10,cv2.BORDER_CONSTANT,value=[198, 203, 208])
                
                #thresholding the image to get the target cell
                image1 = cv2.inRange(image,(80, 80, 180),(180, 170, 245))
                
                # openning errosion then dilation
                kernel = np.ones((3, 3), np.uint8)
                kernel1 = np.ones((5, 5), np.uint8)
                img_erosion = cv2.erode(image1, kernel, iterations=2)
                image1 = cv2.dilate(img_erosion, kernel1, iterations=5)
                
                #detecting the blood cell
                edgedImage = findEdges(image1)
                edgedContours = getImgContours(edgedImage)
                edgedBoxes =  getBoxes(edgedContours, image.copy())
                if len(edgedBoxes)==0:
                    count +=1
                    continue
                # get the large box and get its cordinate
                last = edgedBoxes[-1]
                max_x = int(max(last[:,0]))
                min_x = int( min(last[:,0]))
                max_y = int(max(last[:,1]))
                min_y = int(min(last[:,1]))
                
                # draw the contour and fill it 
                mask = np.zeros_like(image)
                cv2.drawContours(mask, edgedContours, len(edgedContours)-1, (255,255,255), -1) 
                
                # any pixel but the pixels inside the contour is zero
                image[mask==0] = 0
                
                # extract th blood cell
                image = image[min_y:max_y, min_x:max_x]

                if (np.size(image)==0):
                    count +=1
                    continue
                # resize th image
                image = cv2.resize(image, image_size)

                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)

    images = np.array(images, dtype = 'float32')
    labels = np.array(labels, dtype = 'int32')

    return images, labels

# %%
images, labels = load_data(path='/home/user/Desktop/personal/jui/for_Report/generated')
images_t, labels_t = load_data(path='/home/user/Desktop/personal/jui/for_Report/images/TEST')
# Out:
# 100%|██████████| 5620/5620 [00:06<00:00, 839.57it/s]
# 100%|██████████| 5617/5617 [00:07<00:00, 777.25it/s]
# 100%|██████████| 5576/5576 [00:07<00:00, 726.16it/s]
# 100%|██████████| 5586/5586 [00:05<00:00, 931.03it/s]
# 100%|██████████| 672/672 [00:00<00:00, 837.03it/s]
# 100%|██████████| 636/636 [00:00<00:00, 1013.42it/s]
# 100%|██████████| 624/624 [00:00<00:00, 976.44it/s]
# 100%|██████████| 626/626 [00:00<00:00, 973.25it/s]

# %%
images, labels = shuffle(images, labels, random_state=10)
test_images, test_labels = shuffle(images_t, labels_t, random_state=10)

train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size = 0.2)

# %%
n_train = train_labels.shape[0]
n_val = val_labels.shape[0]
n_test = test_labels.shape[0]

print("Number of training examples: {}".format(n_train))
print("Number of validation examples: {}".format(n_val))
print("Number of testing examples: {}".format(n_test))

print("Training images are of shape: {}".format(train_images.shape))
print("Training labels are of shape: {}".format(train_labels.shape))
print("Validation images are of shape: {}".format(val_images.shape))
print("Validation labels are of shape: {}".format(val_labels.shape))
print("Test images are of shape: {}".format(test_images.shape))
print("Test labels are of shape: {}".format(test_labels.shape))
# Out:
# Number of training examples: 17479
# Number of validation examples: 4370
# Number of testing examples: 2497
# Training images are of shape: (17479, 128, 128, 3)
# Training labels are of shape: (17479,)
# Validation images are of shape: (4370, 128, 128, 3)
# Validation labels are of shape: (4370,)
# Test images are of shape: (2497, 128, 128, 3)
# Test labels are of shape: (2497,)

# %%
_, train_counts = np.unique(train_labels, return_counts = True)
_, val_counts = np.unique(val_labels, return_counts = True)
_, test_counts = np.unique(test_labels, return_counts = True)

pd.DataFrame({'train': train_counts, "val": val_counts, "test": test_counts}, index = class_names).plot.bar()

plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
plt.pie(val_counts,
        explode=(0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
plt.pie(test_counts,
        explode=(0.05, 0.05, 0.03, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category in test')
plt.show()

# %%
train_images = train_images / 127.5 -1
val_images = val_images / 127.5 -1
test_images = test_images / 127.5 -1

# %%
def display_random_image (class_names, images, labels):
    print(len(images))
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{}: '.format(index) + class_names[labels[index]])
    plt.show()
    
display_random_image (class_names, train_images, train_labels)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 17479

# %%
def display_examples(class_names, images, labels):
    fig = plt.figure(figsize = (10,10))
    fig.suptitle("Examples of images in the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()
    
display_examples(class_names, train_images, train_labels)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## EfficientNetB7

# %%
from tensorflow.keras.applications import  EfficientNetB7, VGG19, VGG16, ResNet50
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Concatenate


eff = EfficientNetB7(weights='imagenet', include_top=False, input_shape=(128, 128, 3))


for layer in eff.layers:
    layer.trainable = False


input_layer = Input(shape=(128, 128, 3))

x = eff(input_layer)


x = GlobalAveragePooling2D()(x)

x = Dense(units=1024, activation='relu')(x)
x = Dense(units=512, activation='relu')(x)
x = Dense(units=256, activation='relu')(x)

predictions = Dense(4, activation='softmax')(x)

# Create the final model
model_eff = Model(inputs=input_layer, outputs=predictions)
model_eff.compile(optimizer = "adam" , loss = 'sparse_categorical_crossentropy' , metrics = ['accuracy'])
model_eff.summary()

# Implement callbacks 
checkpoint = ModelCheckpoint(filepath='/home/user/Desktop/personal/jui/for_Report/Weights/model_eff.hdf5', save_best_only=True, save_weights_only=False)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=3, verbose = 1, mode='min', restore_best_weights = True)
learning_rate_reduction = ReduceLROnPlateau(
    monitor = 'val_accuracy', 
    patience = 2, 
    verbose = 1, 
    factor = 0.2, 
    min_lr = 0.000001)
import time
start_time = time.time()
# Train
history_eff = model_eff.fit(
    train_images, 
    train_labels, 
    batch_size = 4, 
    epochs = 50, 
    validation_data=(val_images, val_labels), 
    callbacks=[learning_rate_reduction, checkpoint])


end_time = time.time()

print("Execution time:", end_time - start_time, "seconds")
# Out:
# 2023-11-21 16:37:50.234390: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 16:37:50.251467: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 16:37:50.251616: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 16:37:50.252885: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 16:37:50.252972: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 16:37:50.253026: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 16:37:50.483404: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 16:37:50.483547: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 16:37:50.483620: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 16:37:50.483670: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6122 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  efficientnetb7 (Functional  (None, 4, 4, 2560)        64097687
#  )
#
#  global_average_pooling2d (  (None, 2560)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2622464
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 67377307 (257.02 MB)
# Trainable params: 3279620 (12.51 MB)
# Non-trainable params: 64097687 (244.51 MB)
# _________________________________________________________________
# Epoch 1/50
# 2023-11-21 16:38:03.773660: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-11-21 16:38:04.564027: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2023-11-21 16:38:04.939531: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-11-21 16:38:05.406252: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fca4311f250 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-21 16:38:05.406265: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050, Compute Capability 8.6
# 2023-11-21 16:38:05.409019: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-21 16:38:05.464694: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4370/4370 [==============================] - ETA: 0s - loss: 1.3709 - accuracy: 0.2957
# /home/user/anaconda3/envs/tf/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4370/4370 [==============================] - 204s 45ms/step - loss: 1.3709 - accuracy: 0.2957 - val_loss: 1.3110 - val_accuracy: 0.3616 - lr: 0.0010
# Epoch 2/50
# 4370/4370 [==============================] - 196s 45ms/step - loss: 1.3044 - accuracy: 0.3628 - val_loss: 1.2882 - val_accuracy: 0.3700 - lr: 0.0010
# Epoch 3/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2750 - accuracy: 0.3817 - val_loss: 1.2466 - val_accuracy: 0.3709 - lr: 0.0010
# Epoch 4/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2708 - accuracy: 0.3829 - val_loss: 1.2736 - val_accuracy: 0.3872 - lr: 0.0010
# Epoch 5/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2668 - accuracy: 0.3822 - val_loss: 1.2542 - val_accuracy: 0.3936 - lr: 0.0010
# Epoch 6/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2615 - accuracy: 0.3873 - val_loss: 1.2209 - val_accuracy: 0.4176 - lr: 0.0010
# Epoch 7/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2569 - accuracy: 0.3896 - val_loss: 1.2559 - val_accuracy: 0.4041 - lr: 0.0010
# Epoch 8/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2548 - accuracy: 0.3971 - val_loss: 1.2199 - val_accuracy: 0.4220 - lr: 0.0010
# Epoch 9/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2524 - accuracy: 0.3973 - val_loss: 1.2134 - val_accuracy: 0.4272 - lr: 0.0010
# Epoch 10/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2514 - accuracy: 0.3927 - val_loss: 1.2284 - val_accuracy: 0.4178 - lr: 0.0010
# Epoch 11/50
# 4369/4370 [============================>.] - ETA: 0s - loss: 1.2501 - accuracy: 0.3932
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2500 - accuracy: 0.3933 - val_loss: 1.2145 - val_accuracy: 0.4144 - lr: 0.0010
# Epoch 12/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2337 - accuracy: 0.4041 - val_loss: 1.2093 - val_accuracy: 0.4249 - lr: 2.0000e-04
# Epoch 13/50
# 4370/4370 [==============================] - ETA: 0s - loss: 1.2337 - accuracy: 0.4011
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2337 - accuracy: 0.4011 - val_loss: 1.2197 - val_accuracy: 0.4112 - lr: 2.0000e-04
# Epoch 14/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2308 - accuracy: 0.4065 - val_loss: 1.2064 - val_accuracy: 0.4265 - lr: 4.0000e-05
# Epoch 15/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2268 - accuracy: 0.4059 - val_loss: 1.2047 - val_accuracy: 0.4286 - lr: 4.0000e-05
# Epoch 16/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2276 - accuracy: 0.4067 - val_loss: 1.2030 - val_accuracy: 0.4311 - lr: 4.0000e-05
# Epoch 17/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2263 - accuracy: 0.4080 - val_loss: 1.2029 - val_accuracy: 0.4320 - lr: 4.0000e-05
# Epoch 18/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2277 - accuracy: 0.4108 - val_loss: 1.2026 - val_accuracy: 0.4320 - lr: 4.0000e-05
# Epoch 19/50
# 4369/4370 [============================>.] - ETA: 0s - loss: 1.2278 - accuracy: 0.4080
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2278 - accuracy: 0.4080 - val_loss: 1.2038 - val_accuracy: 0.4297 - lr: 4.0000e-05
# Epoch 20/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2236 - accuracy: 0.4073 - val_loss: 1.2022 - val_accuracy: 0.4307 - lr: 8.0000e-06
# Epoch 21/50
# 4370/4370 [==============================] - ETA: 0s - loss: 1.2227 - accuracy: 0.4129
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2227 - accuracy: 0.4129 - val_loss: 1.2022 - val_accuracy: 0.4302 - lr: 8.0000e-06
# Epoch 22/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2220 - accuracy: 0.4096 - val_loss: 1.2014 - val_accuracy: 0.4307 - lr: 1.6000e-06
# Epoch 23/50
# 4369/4370 [============================>.] - ETA: 0s - loss: 1.2224 - accuracy: 0.4114
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2224 - accuracy: 0.4113 - val_loss: 1.2011 - val_accuracy: 0.4309 - lr: 1.6000e-06
# Epoch 24/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2232 - accuracy: 0.4103 - val_loss: 1.2008 - val_accuracy: 0.4325 - lr: 1.0000e-06
# Epoch 25/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2217 - accuracy: 0.4101 - val_loss: 1.2009 - val_accuracy: 0.4316 - lr: 1.0000e-06
# Epoch 26/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2211 - accuracy: 0.4114 - val_loss: 1.2008 - val_accuracy: 0.4311 - lr: 1.0000e-06
# Epoch 27/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2234 - accuracy: 0.4073 - val_loss: 1.2008 - val_accuracy: 0.4307 - lr: 1.0000e-06
# Epoch 28/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2230 - accuracy: 0.4128 - val_loss: 1.2007 - val_accuracy: 0.4311 - lr: 1.0000e-06
# Epoch 29/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2224 - accuracy: 0.4076 - val_loss: 1.2008 - val_accuracy: 0.4304 - lr: 1.0000e-06
# Epoch 30/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2224 - accuracy: 0.4076 - val_loss: 1.2007 - val_accuracy: 0.4307 - lr: 1.0000e-06
# Epoch 31/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2212 - accuracy: 0.4119 - val_loss: 1.2008 - val_accuracy: 0.4314 - lr: 1.0000e-06
# Epoch 32/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2282 - accuracy: 0.4075 - val_loss: 1.2006 - val_accuracy: 0.4307 - lr: 1.0000e-06
# Epoch 33/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2222 - accuracy: 0.4075 - val_loss: 1.2005 - val_accuracy: 0.4302 - lr: 1.0000e-06
# Epoch 34/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2256 - accuracy: 0.4094 - val_loss: 1.2004 - val_accuracy: 0.4311 - lr: 1.0000e-06
# Epoch 35/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2200 - accuracy: 0.4119 - val_loss: 1.2003 - val_accuracy: 0.4300 - lr: 1.0000e-06
# Epoch 36/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2223 - accuracy: 0.4100 - val_loss: 1.2003 - val_accuracy: 0.4304 - lr: 1.0000e-06
# Epoch 37/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2230 - accuracy: 0.4079 - val_loss: 1.2002 - val_accuracy: 0.4309 - lr: 1.0000e-06
# Epoch 38/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2209 - accuracy: 0.4115 - val_loss: 1.2003 - val_accuracy: 0.4311 - lr: 1.0000e-06
# Epoch 39/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2233 - accuracy: 0.4087 - val_loss: 1.2001 - val_accuracy: 0.4302 - lr: 1.0000e-06
# Epoch 40/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2247 - accuracy: 0.4104 - val_loss: 1.2001 - val_accuracy: 0.4309 - lr: 1.0000e-06
# Epoch 41/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2258 - accuracy: 0.4085 - val_loss: 1.2002 - val_accuracy: 0.4311 - lr: 1.0000e-06
# Epoch 42/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2222 - accuracy: 0.4110 - val_loss: 1.1997 - val_accuracy: 0.4311 - lr: 1.0000e-06
# Epoch 43/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2216 - accuracy: 0.4131 - val_loss: 1.1997 - val_accuracy: 0.4311 - lr: 1.0000e-06
# Epoch 44/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2243 - accuracy: 0.4085 - val_loss: 1.1995 - val_accuracy: 0.4327 - lr: 1.0000e-06
# Epoch 45/50
# 4370/4370 [==============================] - 199s 45ms/step - loss: 1.2243 - accuracy: 0.4076 - val_loss: 1.1994 - val_accuracy: 0.4325 - lr: 1.0000e-06
# Epoch 46/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2225 - accuracy: 0.4110 - val_loss: 1.1994 - val_accuracy: 0.4332 - lr: 1.0000e-06
# Epoch 47/50
# 4370/4370 [==============================] - 198s 45ms/step - loss: 1.2180 - accuracy: 0.4154 - val_loss: 1.1994 - val_accuracy: 0.4325 - lr: 1.0000e-06
# Epoch 48/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2207 - accuracy: 0.4114 - val_loss: 1.1994 - val_accuracy: 0.4334 - lr: 1.0000e-06
# Epoch 49/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2210 - accuracy: 0.4156 - val_loss: 1.1990 - val_accuracy: 0.4339 - lr: 1.0000e-06
# Epoch 50/50
# 4370/4370 [==============================] - 199s 46ms/step - loss: 1.2221 - accuracy: 0.4119 - val_loss: 1.1990 - val_accuracy: 0.4330 - lr: 1.0000e-06
# Execution time: 9937.18497133255 seconds

# %%
from keras import backend as K

K.clear_session()

physical_devices = tf.config.list_physical_devices('GPU')

# %% [markdown]
# ## ResNEt50

# %%
from tensorflow.keras.applications import  MobileNet, VGG19, VGG16, ResNet50
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Concatenate


res = ResNet50(weights='imagenet', include_top=False, input_shape=(128, 128, 3))


for layer in res.layers:
    layer.trainable = False


input_layer = Input(shape=(128, 128, 3))

x = res(input_layer)


x = GlobalAveragePooling2D()(x)

x = Dense(units=1024, activation='relu')(x)
x = Dense(units=512, activation='relu')(x)
x = Dense(units=256, activation='relu')(x)

predictions = Dense(4, activation='softmax')(x)

# Create the final model
model_res = Model(inputs=input_layer, outputs=predictions)
model_res.compile(optimizer = "adam" , loss = 'sparse_categorical_crossentropy' , metrics = ['accuracy'])
model_res.summary()

# Implement callbacks 
checkpoint = ModelCheckpoint(filepath='/home/user/Desktop/personal/jui/for_Report/Weights/model_res.hdf5', save_best_only=True, save_weights_only=False)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=3, verbose = 1, mode='min', restore_best_weights = True)
learning_rate_reduction = ReduceLROnPlateau(
    monitor = 'val_accuracy', 
    patience = 2, 
    verbose = 1, 
    factor = 0.2, 
    min_lr = 0.000001)
import time
start_time = time.time()
# Train
history_res = model_res.fit(
    train_images, 
    train_labels, 
    batch_size = 4, 
    epochs = 50, 
    validation_data=(val_images, val_labels), 
    callbacks=[learning_rate_reduction, checkpoint])


end_time = time.time()

print("Execution time:", end_time - start_time, "seconds")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 26343044 (100.49 MB)
# Trainable params: 2755332 (10.51 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________
# Epoch 1/50
# 4370/4370 [==============================] - 94s 21ms/step - loss: 1.2172 - accuracy: 0.4229 - val_loss: 1.1368 - val_accuracy: 0.4886 - lr: 0.0010
# Epoch 2/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 1.0932 - accuracy: 0.4995 - val_loss: 1.0555 - val_accuracy: 0.5224 - lr: 0.0010
# Epoch 3/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 1.0345 - accuracy: 0.5346 - val_loss: 1.0631 - val_accuracy: 0.5087 - lr: 0.0010
# Epoch 4/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.9933 - accuracy: 0.5588 - val_loss: 0.9980 - val_accuracy: 0.5526 - lr: 0.0010
# Epoch 5/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.9646 - accuracy: 0.5735 - val_loss: 1.0100 - val_accuracy: 0.5410 - lr: 0.0010
# Epoch 6/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.9462 - accuracy: 0.5834 - val_loss: 0.9502 - val_accuracy: 0.5741 - lr: 0.0010
# Epoch 7/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.9263 - accuracy: 0.5931 - val_loss: 0.9348 - val_accuracy: 0.5881 - lr: 0.0010
# Epoch 8/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.9059 - accuracy: 0.6020 - val_loss: 0.9437 - val_accuracy: 0.5881 - lr: 0.0010
# Epoch 9/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.8897 - accuracy: 0.6128 - val_loss: 0.9195 - val_accuracy: 0.5947 - lr: 0.0010
# Epoch 10/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.8743 - accuracy: 0.6203 - val_loss: 0.9019 - val_accuracy: 0.6151 - lr: 0.0010
# Epoch 11/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.8616 - accuracy: 0.6305 - val_loss: 0.9519 - val_accuracy: 0.5613 - lr: 0.0010
# Epoch 12/50
# 4368/4370 [============================>.] - ETA: 0s - loss: 0.8421 - accuracy: 0.6329
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.8420 - accuracy: 0.6329 - val_loss: 0.9255 - val_accuracy: 0.5959 - lr: 0.0010
# Epoch 13/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.7623 - accuracy: 0.6749 - val_loss: 0.8766 - val_accuracy: 0.6302 - lr: 2.0000e-04
# Epoch 14/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.7445 - accuracy: 0.6808 - val_loss: 0.8793 - val_accuracy: 0.6332 - lr: 2.0000e-04
# Epoch 15/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.7361 - accuracy: 0.6847 - val_loss: 0.8888 - val_accuracy: 0.6302 - lr: 2.0000e-04
# Epoch 16/50
# 4370/4370 [==============================] - ETA: 0s - loss: 0.7283 - accuracy: 0.6901
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.7283 - accuracy: 0.6901 - val_loss: 0.9132 - val_accuracy: 0.6314 - lr: 2.0000e-04
# Epoch 17/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.7062 - accuracy: 0.7010 - val_loss: 0.8874 - val_accuracy: 0.6403 - lr: 4.0000e-05
# Epoch 18/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.7021 - accuracy: 0.7025 - val_loss: 0.8908 - val_accuracy: 0.6375 - lr: 4.0000e-05
# Epoch 19/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6996 - accuracy: 0.7034 - val_loss: 0.8937 - val_accuracy: 0.6430 - lr: 4.0000e-05
# Epoch 20/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6979 - accuracy: 0.7031 - val_loss: 0.8919 - val_accuracy: 0.6366 - lr: 4.0000e-05
# Epoch 21/50
# 4370/4370 [==============================] - ETA: 0s - loss: 0.6965 - accuracy: 0.7035
# Epoch 21: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6965 - accuracy: 0.7035 - val_loss: 0.8954 - val_accuracy: 0.6419 - lr: 4.0000e-05
# Epoch 22/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6905 - accuracy: 0.7091 - val_loss: 0.8942 - val_accuracy: 0.6414 - lr: 8.0000e-06
# Epoch 23/50
# 4368/4370 [============================>.] - ETA: 0s - loss: 0.6900 - accuracy: 0.7085
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6900 - accuracy: 0.7086 - val_loss: 0.8950 - val_accuracy: 0.6426 - lr: 8.0000e-06
# Epoch 24/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6886 - accuracy: 0.7097 - val_loss: 0.8948 - val_accuracy: 0.6419 - lr: 1.6000e-06
# Epoch 25/50
# 4369/4370 [============================>.] - ETA: 0s - loss: 0.6885 - accuracy: 0.7093
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-06.
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6884 - accuracy: 0.7093 - val_loss: 0.8947 - val_accuracy: 0.6412 - lr: 1.6000e-06
# Epoch 26/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6882 - accuracy: 0.7105 - val_loss: 0.8947 - val_accuracy: 0.6421 - lr: 1.0000e-06
# Epoch 27/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6882 - accuracy: 0.7103 - val_loss: 0.8948 - val_accuracy: 0.6426 - lr: 1.0000e-06
# Epoch 28/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6881 - accuracy: 0.7093 - val_loss: 0.8949 - val_accuracy: 0.6412 - lr: 1.0000e-06
# Epoch 29/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6880 - accuracy: 0.7105 - val_loss: 0.8948 - val_accuracy: 0.6416 - lr: 1.0000e-06
# Epoch 30/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6880 - accuracy: 0.7098 - val_loss: 0.8949 - val_accuracy: 0.6410 - lr: 1.0000e-06
# Epoch 31/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6879 - accuracy: 0.7103 - val_loss: 0.8950 - val_accuracy: 0.6421 - lr: 1.0000e-06
# Epoch 32/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6879 - accuracy: 0.7102 - val_loss: 0.8951 - val_accuracy: 0.6426 - lr: 1.0000e-06
# Epoch 33/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6878 - accuracy: 0.7103 - val_loss: 0.8951 - val_accuracy: 0.6426 - lr: 1.0000e-06
# Epoch 34/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6878 - accuracy: 0.7099 - val_loss: 0.8952 - val_accuracy: 0.6423 - lr: 1.0000e-06
# Epoch 35/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6878 - accuracy: 0.7109 - val_loss: 0.8952 - val_accuracy: 0.6421 - lr: 1.0000e-06
# Epoch 36/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6877 - accuracy: 0.7102 - val_loss: 0.8952 - val_accuracy: 0.6426 - lr: 1.0000e-06
# Epoch 37/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6876 - accuracy: 0.7106 - val_loss: 0.8953 - val_accuracy: 0.6423 - lr: 1.0000e-06
# Epoch 38/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6876 - accuracy: 0.7107 - val_loss: 0.8954 - val_accuracy: 0.6428 - lr: 1.0000e-06
# Epoch 39/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6875 - accuracy: 0.7106 - val_loss: 0.8955 - val_accuracy: 0.6426 - lr: 1.0000e-06
# Epoch 40/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6875 - accuracy: 0.7103 - val_loss: 0.8955 - val_accuracy: 0.6423 - lr: 1.0000e-06
# Epoch 41/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6874 - accuracy: 0.7107 - val_loss: 0.8955 - val_accuracy: 0.6428 - lr: 1.0000e-06
# Epoch 42/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6874 - accuracy: 0.7107 - val_loss: 0.8956 - val_accuracy: 0.6423 - lr: 1.0000e-06
# Epoch 43/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6873 - accuracy: 0.7102 - val_loss: 0.8956 - val_accuracy: 0.6419 - lr: 1.0000e-06
# Epoch 44/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6873 - accuracy: 0.7107 - val_loss: 0.8957 - val_accuracy: 0.6421 - lr: 1.0000e-06
# Epoch 45/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6872 - accuracy: 0.7106 - val_loss: 0.8958 - val_accuracy: 0.6421 - lr: 1.0000e-06
# Epoch 46/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6872 - accuracy: 0.7106 - val_loss: 0.8959 - val_accuracy: 0.6423 - lr: 1.0000e-06
# Epoch 47/50
# 4370/4370 [==============================] - 90s 21ms/step - loss: 0.6871 - accuracy: 0.7110 - val_loss: 0.8958 - val_accuracy: 0.6423 - lr: 1.0000e-06
# Epoch 48/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6871 - accuracy: 0.7110 - val_loss: 0.8959 - val_accuracy: 0.6430 - lr: 1.0000e-06
# Epoch 49/50
# 4370/4370 [==============================] - 91s 21ms/step - loss: 0.6870 - accuracy: 0.7111 - val_loss: 0.8958 - val_accuracy: 0.6426 - lr: 1.0000e-06
# Epoch 50/50
# 4370/4370 [==============================] - 90s 20ms/step - loss: 0.6870 - accuracy: 0.7109 - val_loss: 0.8959 - val_accuracy: 0.6423 - lr: 1.0000e-06
# Execution time: 4535.365839958191 seconds

# %%
from keras import backend as K

K.clear_session()

physical_devices = tf.config.list_physical_devices('GPU')

# %% [markdown]
# ## **VGG16**

# %%
from tensorflow.keras.applications import  MobileNet, VGG19, VGG16, ResNet50
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Concatenate


vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))


for layer in vgg16.layers:
    layer.trainable = False


input_layer = Input(shape=(128, 128, 3))

x = vgg16(input_layer)


x = GlobalAveragePooling2D()(x)

x = Dense(units=1024, activation='relu')(x)
x = Dense(units=512, activation='relu')(x)
x = Dense(units=256, activation='relu')(x)

predictions = Dense(4, activation='softmax')(x)

# Create the final model
model_vgg16 = Model(inputs=input_layer, outputs=predictions)
model_vgg16.compile(optimizer = "adam" , loss = 'sparse_categorical_crossentropy' , metrics = ['accuracy'])
model_vgg16.summary()

# Implement callbacks 
checkpoint = ModelCheckpoint(filepath='/home/user/Desktop/personal/jui/for_Report/Weights/model_vgg16.hdf5', save_best_only=True, save_weights_only=False)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=3, verbose = 1, mode='min', restore_best_weights = True)
learning_rate_reduction = ReduceLROnPlateau(
    monitor = 'val_accuracy', 
    patience = 2, 
    verbose = 1, 
    factor = 0.2, 
    min_lr = 0.000001)
import time
start_time = time.time()
# Train
history_vgg16 = model_vgg16.fit(
    train_images, 
    train_labels, 
    batch_size = 4, 
    epochs = 50, 
    validation_data=(val_images, val_labels), 
    callbacks=[learning_rate_reduction, checkpoint])


end_time = time.time()

print("Execution time:", end_time - start_time, "seconds")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 15897156 (60.64 MB)
# Trainable params: 1182468 (4.51 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
from keras import backend as K

K.clear_session()

physical_devices = tf.config.list_physical_devices('GPU')

# %% [markdown]
# # **VGG19**

# %%
from tensorflow.keras.applications import  MobileNet, VGG19, VGG16, ResNet50
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Concatenate


vgg19 = VGG19(weights='imagenet', include_top=False, input_shape=(128, 128, 3))


for layer in vgg19.layers:
    layer.trainable = False


input_layer = Input(shape=(128, 128, 3))

x = vgg19(input_layer)


x = GlobalAveragePooling2D()(x)

x = Dense(units=1024, activation='relu')(x)
x = Dense(units=512, activation='relu')(x)
x = Dense(units=256, activation='relu')(x)

predictions = Dense(4, activation='softmax')(x)

# Create the final model
model_vgg19 = Model(inputs=input_layer, outputs=predictions)
model_vgg19.compile(optimizer = "adam" , loss = 'sparse_categorical_crossentropy' , metrics = ['accuracy'])
model_vgg19.summary()

# Implement callbacks 
checkpoint = ModelCheckpoint(filepath='/home/user/Desktop/personal/jui/for_Report/Weights/model_vgg19.hdf5', save_best_only=True, save_weights_only=False)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=3, verbose = 1, mode='min', restore_best_weights = True)
learning_rate_reduction = ReduceLROnPlateau(
    monitor = 'val_accuracy', 
    patience = 2, 
    verbose = 1, 
    factor = 0.2, 
    min_lr = 0.000001)
import time
start_time = time.time()
# Train
history_vgg19 = model_vgg19.fit(
    train_images, 
    train_labels, 
    batch_size = 4, 
    epochs = 50, 
    validation_data=(val_images, val_labels), 
    callbacks=[learning_rate_reduction, checkpoint])


end_time = time.time()

# %%
print("Execution time:", end_time - start_time, "seconds")

# %%
from keras import backend as K

K.clear_session()

physical_devices = tf.config.list_physical_devices('GPU')

# %% [markdown]
# # Evaluating performance
#
# Following model training I emplemented a helper function to plot Accuracy vs Epoch and Loss vs Epoch for both the Training and Validation sets

# %%
def plot_accuracy_loss_chart(history):
    epochs = [i for i in range(50)]
    fig , ax = plt.subplots(1,2)
    train_acc = history.history['accuracy']
    train_loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    fig.set_size_inches(20,10)
    ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
    ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
    ax[0].set_title('Training & Validation Accuracy')
    ax[0].legend()
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Accuracy")

    ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
    ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
    ax[1].set_title('Training & Validation Loss')
    ax[1].legend()
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("Training & Validation Loss")
    plt.show()

# %%
plot_accuracy_loss_chart(history1)

# %% [markdown]
# Lets evaluate the model on test data to find the loss and accuracy:

# %% [markdown]
# Model (and weights) are saved after training. The best model and its weights can also be saved using the ModelCheckpoint callback if "EarlyStopping" is activated in the Model.fit phase. [More on this here](https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/)
#
# I decided against using EarlyStopping, but I will try to include it in future work on this dataset.

# %%
model1.save('/home/user/Desktop/personal/jui/for_Report/Weights/vgg19.hdf5')

# %%
K.clear_session()

# %%
model_weight = tf.keras.models.load_model('/home/user/Desktop/personal/jui/for_Report/Weights/vgg19.hdf5')

# %%
results = model_weight.evaluate(train_images, train_labels)

print("Loss of the model  is - train ", results[0])
print("Accuracy of the model is - train", results[1]*100, "%")

results = model_weight.evaluate(test_images, test_labels)

print("Loss of the model  is - test ", results[0])
print("Accuracy of the model is - test", results[1]*100, "%")


results = model_weight.evaluate(val_images, val_labels)

print("Loss of the model  is - val ", results[0])
print("Accuracy of the model is - val", results[1]*100, "%")

# %%
from sklearn.metrics import classification_report

predictions = model_weight.predict(test_images)
predictions = np.argmax(predictions,axis=1)
predictions[:15]

# %%
print(classification_report(
    test_labels, 
    predictions, 
    target_names = ['EOSINOPHIL (Class 0)', 'LYMPHOCYTE (Class 1)', 'MONOCYTE (Class 2)', 'NEUTROPHIL (Class 3)']))

# %%
cm = confusion_matrix(test_labels, predictions)
cm = pd.DataFrame(cm, index = ['0', '1', '2', '3'], columns = ['0', '1', '2', '3'])
cm

# %%
def plot_confusion_matrix (cm):
    plt.figure(figsize = (10,10))
    sns.heatmap(
        cm, 
        cmap = 'Blues', 
        linecolor = 'black', 
        linewidth = 1, 
        annot = True, 
        fmt = '', 
        xticklabels = class_names, 
        yticklabels = class_names)
    
plot_confusion_matrix(cm)
